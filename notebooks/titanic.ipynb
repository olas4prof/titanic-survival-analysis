# %% [markdown]
# <h1 style="color:red; text-align:center;"><b>TITANIC PYTHON PROJECT</b></h1>

# %% [markdown]
# <h2 style="color:green;">Libraries Importation</h2>

# %%
import sys
from pathlib import Path
sys.path.append(str(Path().resolve().parent))

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# <h2 style="color:green;">Data Importation and Loading</h2>

# %%
df = load_data()
df.head()
# Out:
#    PassengerId  Pclass             Name     Sex  Age  SibSp  Parch  \
# 0            1       3     Allison Hill    male   17      4      2
# 1            2       1      Noah Rhodes    male   60      2      2
# 2            3       3  Angie Henderson    male   64      0      0
# 3            4       3    Daniel Wagner    male   35      4      0
# 4            5       1  Cristian Santos  female   70      0      3
#
#                                  Ticket    Fare Embarked  Survived
# 0  43d75413-a939-4bd1-a516-b0d47d3572cc  144.08        Q         1
# 1  6334fa2a-8b4b-47e7-a451-5ae01754bf08  249.04        S         0
# 2  61a66444-e2af-4629-9efb-336e2f546033   50.31        Q         1
# 3  0b6c03c8-721e-4419-afc3-e6495e911b91  235.20        C         1
# 4  436e3c49-770e-49db-b092-d40143675d58  160.17        C         1

# %% [markdown]
# <h2 style="color:green;">Standardization and Capitalisation of 'Sex'column</h2>

# %%
df['Sex'] = df['Sex'].str.capitalize().str.strip()
df.head(6)

# %% [markdown]
# <h2 style="color:green;">Checking for Data types</h2>

# %%
df.dtypes

# %% [markdown]
# <h2 style="color:green;">Checking for Missing Value(s)</h2>

# %%
df.isnull().sum()

# %% [markdown]
# <h2 style="color:green;">Checking for Duplicate(s)</h2>

# %%
df.duplicated().sum()

# %% [markdown]
# <h2 style="color:green;">Statistical Summary of Numeric Columns</h2>

# %%
df.describe()

# %% [markdown]
# <h2 style="color:green;">ANALYSIS</h2>

# %% [markdown]
# <h3 style="color:green;">1. Overall survival rate</h3>

# %%
overall_survival_rate(df)
print(overall_survival_rate(df))
# Out:
# 49.2%

# %% [markdown]
# <h3 style="color:green;">2. Survival Rate by Gender</h3>

# %%
survival_by_gender(df)
# Out:
# Sex
# Female    48.4%
# Male      49.9%
# Name: Survived, dtype: object

# %% [markdown]
# <h3 style="color:green;">3. Survival rate by passenger class</h3>

# %%
survival_by_class(df)
# Out:
# Pclass
# 1    48.2%
# 2    48.5%
# 3    51.1%
# Name: Survived, dtype: object

# %% [markdown]
# <h3 style="color:green;">4. Age distribution</h3>

# %%
df['Age'].describe()

# %%
df['AgeGroup'] = np.where(df['Age'] < 13, 'Child (0–12)',  # Using nested np.where
                   np.where(df['Age'] < 18, 'Teen (13–18)',
                   np.where(df['Age'] < 30, 'Young Adult (19–30)',
                   np.where(df['Age'] < 50, 'Adult (31–50)',
                            'Senior (51+)'))))
df.head()

# %%
age_distribution = df.groupby('AgeGroup')['PassengerId'].count().sort_values(ascending= False)
age_distribution_df = age_distribution.reset_index()
age_distribution_df.columns = ['Age Group', 'Count']
print(age_distribution_df)

# %% [markdown]
# <h3 style="color:green;">ADDITIONAL TWO QUESTIONS</h3>

# %% [markdown]
# <h3 style="color:green;">1. Survival rate by age group</h3>

# %%
survival_rate_by_age = (df.groupby('AgeGroup')['Survived'].mean() * 100).sort_values(ascending= False)
print('AgeGroup')
for agegroup, rate in survival_by_age.items():
    print(f"{agegroup}: {rate:.1f}%")

# %% [markdown]
# <h3 style="color:green;">2. Average fare by passenger class</h3>

# %%
avg_fare_by_class = df.groupby('Pclass')['Fare'].mean().sort_values(ascending= False)
print(avg_fare_by_class)

# %% [markdown]
# <h2 style="color:green;">VISUALIZATION</h2>

# %% [markdown]
# <h3 style="color:green;">Passenger Gender Distribution</h3>

# %%
plt.figure(figsize=(6,3))
df['Sex'].value_counts().plot(
    kind='barh',
    color='red',
    edgecolor='black'
)
plt.title('Passenger Gender Distribution')
plt.xlabel('Gender')
plt.ylabel('Number of Passengers')
plt.show()

# %% [markdown]
# <h3 style="color:green;">Survival by Passenger Class</h3>

# %%
survival_rate_by_pclass

# %%
survival_rate_by_pclass = df.groupby('Pclass')['Survived'].mean() * 100
survival_rate_by_pclass.plot(kind= 'bar', color= 'red',figsize=(6,4))
plt.xticks(rotation=360)
plt.ylabel('Survival Rate(%)')
plt.title('Survival by passenger class')
plt.ylim(0, 60)
plt.gcf().set_facecolor('lightgray')    # outer area (around the chart)
plt.gca().set_facecolor('lightgray')  # inside chart area

# %% [markdown]
# <h3 style="color:green;">Average Fare by Class</h3>

# %%
print(avg_fare_by_class)
avg_fare_by_class.plot(kind= 'barh', color= 'red', figsize= (7,3))
plt.xlabel('Average Fare')
plt.ylabel('Passenger Class')
plt.title('Average Fare by Class')
plt.gcf().set_facecolor('lightgray')    # outer area (around the chart)
plt.gca().set_facecolor('lightgray')  # inside chart area

# %% [markdown]
# <h3 style="color:green;">Age Distribution</h3>

# %%
plt.figure(figsize=(7,4))
sns.histplot(df['Age'].dropna(), bins=20, kde=True, color='red', edgecolor='black')
plt.title('Age Distribution of Passengers')
plt.xlabel('Age')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# <h3 style="color:green;">Survival by Gender</h3>

# %%
survival_rate_by_gender

# %%
plt.figure(figsize=(5,4))
survival_rate_by_gender.plot(
    kind='bar',
    color= 'red',
    edgecolor='black'
)
plt.title('Survival Rate by Gender')
plt.xlabel('Gender')
plt.ylabel('Survival Rate (%)')
plt.ylim(0, 60)
plt.xticks(rotation= 45)
plt.gcf().set_facecolor('lightgray')    # outer area (around the chart)
plt.gca().set_facecolor('lightgray')
plt.show()

# %% [markdown]
# <h3 style="color:green;">Correlation Heatmap</h3>

# %%
corr = df.corr(numeric_only=True)
plt.figure(figsize=(7, 5))
sns.heatmap(corr, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Heatmap')
plt.xticks(rotation=45)
plt.gcf().set_facecolor('lightgray')    # outer area (around the chart)
plt.gca().set_facecolor('lightgray')  # inside chart area
plt.show()

# %% [raw]
# A heatmap is a colored grid (or table) that shows relationships (correlations) between numerical variables.
# Each cell’s color represents the strength and direction of a relationship:
# 🔴 Red / Warm colors → strong positive correlation (when one increases, the other also increases)
#
# 🔵 Blue / Cool colors → strong negative correlation (when one increases, the other decreases)
#
# ⚪ White / Neutral colors → little or no correlation
#
# Color	Meaning
# 🔴 Red	Strong positive correlation (close to +1)
# 🔵 Blue	Strong negative correlation (close to -1)
# ⚪ White	Little or no correlation (close to 0)
# In your Titanic data, you’re seeing that most numerical features have weak correlations, which is expected — survival depends on multiple complex factors (not just linear numeric ones).

# %%
df.head(5)

# %%
age_group

# %%
age_group = df.groupby('AgeGroup')['Survived'].mean() * 100
age_group.plot(kind= 'bar', color= 'red',figsize=(6,4))
plt.xticks(rotation=30)
plt.ylabel('Survival Rate(%)')
plt.title('Survival by Age Group')
plt.ylim(0, 60)
plt.gcf().set_facecolor('lightgray')    # outer area (around the chart)
plt.gca().set_facecolor('lightgray')  # inside chart area

# %% [markdown]
# <h3 style="color:green;">Survival Rate by Number of Siblings</h3>

# %%
sibsp= df.groupby('SibSp')['Survived'].mean()*100
sibsp

# %%
plt.figure(figsize=(5,4))
sibsp.plot(
    kind='bar',
    color= 'red',
    edgecolor='black'
)
plt.title('Survival Rate by Siblings')
plt.xlabel('No of Siblings')
plt.ylabel('Survival Rate (%)')
plt.ylim(0, 60)
plt.xticks(rotation= 360)
plt.gcf().set_facecolor('lightgray')    # outer area (around the chart)
plt.gca().set_facecolor('lightgray')
plt.show()

# %% [raw]
# This is a contradictory result to the typical titanic pattern

# %% [markdown]
# <h3 style="color:green;">Survival Rate by Number of Parents or Children</h3>

# %%
parch = (df.groupby('Parch')['Survived'].mean()*100)
parch

# %%
plt.figure(figsize=(7,4))
parch.plot(
    kind='bar',
    color= 'red',
    edgecolor='black'
)
plt.title('Survival Rate by Dependents')
plt.xlabel('No of Parents/Children')
plt.ylabel('Survival Rate (%)')
plt.ylim(0, 60)
plt.xticks(rotation= 360)
plt.gcf().set_facecolor('lightgray')    # outer area (around the chart)
plt.gca().set_facecolor('lightgray')
plt.show()
